# %%
import logging
import matplotlib
import pandas as pd
import seaborn
import requests

# %%
drug_c = pd.read_csv("drugCentral.csv")
endogenous = pd.read_csv("endogenous.csv")
in_trails = pd.read_csv("in-trials.csv")
world = pd.read_csv("world.csv")

# %%
drug_c.head(15)
# Out:
#     Unnamed: 0                                             SMILES  \
# 0            0              CCCCN1CCCC[C@H]1C(=O)NC1=C(C)C=CC=C1C
# 1            1  COC(=O)C1=C(C)NC(C)=C([C@H]1C1=CC(=CC=C1)[N+](...
# 2            2  CCOC(=O)C1=C(C)NC(C)=C([C@@H]1C1=CC(=CC=C1)[N+...
# 3            3      C[C@@H](CCC1=CC=C(O)C=C1)NCCC1=CC=C(O)C(O)=C1
# 4            4  NC1=NC2=NC=C(CNC3=CC=C(C=C3)C(=O)N[C@@H](CCC(O...
# 5            5                              NCC1=CC=C(C=C1)C(O)=O
# 6            6                               OC(=O)CCCC1=CC=CC=C1
# 7            7  NC1=NC(=O)N(C=N1)[C@@H]1O[C@H](CO)[C@@H](O)[C@...
# 8            8                                   FC1=CNC(=O)NC1=O
# 9            9  CC(=O)OC[C@H]1O[C@H]([C@H](OC(C)=O)[C@@H]1OC(C...
# 10          10                     COC1=C2OC=CC2=CC2=C1OC(=O)C=C2
# 11          11  CC(=O)OCC(=O)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H]...
# 12          12  NC1=NC(NC2CC2)=C2N=CN([C@@H]3C[C@H](CO)C=C3)C2=N1
# 13          13  CC(C)C[C@H](NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 14          14  NC(=O)C1=C(N)N(C=N1)[C@@H]1O[C@H](CO)[C@@H](O)...
#
#                                                 InChI  \
# 0   InChI=1S/C18H28N2O/c1-4-5-12-20-13-7-6-11-16(2...
# 1   InChI=1S/C26H29N3O6/c1-17-22(25(30)34-4)24(20-...
# 2   InChI=1S/C18H20N2O6/c1-5-26-18(22)15-11(3)19-1...
# 3   InChI=1S/C18H23NO3/c1-13(2-3-14-4-7-16(20)8-5-...
# 4   InChI=1S/C19H20N8O5/c20-15-14-16(27-19(21)26-1...
# 5   InChI=1S/C8H9NO2/c9-5-6-1-3-7(4-2-6)8(10)11/h1...
# 6   InChI=1S/C10H12O2/c11-10(12)8-4-7-9-5-2-1-3-6-...
# 7   InChI=1S/C8H12N4O5/c9-7-10-2-12(8(16)11-7)6-5(...
# 8   InChI=1S/C4H3FN2O2/c5-2-1-6-4(9)7-3(2)8/h1H,(H...
# 9   InChI=1S/C14H17N3O9/c1-6(18)23-5-9-11(24-7(2)1...
# 10  InChI=1S/C12H8O4/c1-14-12-10-8(4-5-15-10)6-7-2...
# 11  InChI=1S/C23H34O4/c1-14(24)27-13-21(26)20-7-6-...
# 12  InChI=1S/C14H18N6O/c15-14-18-12(17-9-2-3-9)11-...
# 13  InChI=1S/C72H95ClN14O14/c1-41(2)32-54(64(93)80...
# 14  InChI=1S/C9H14N4O5/c10-7-4(8(11)17)12-2-13(7)9...
#
#                        InChIKey  ID                      INN       CAS_RN
# 0   LEBVLXFERQHONN-INIZCTEOSA-N   4          levobupivacaine   27262-47-1
# 1   ZBBHBTPTTSWHBA-DEOSSOPVSA-N   5          (S)-nicardipine   76093-36-2
# 2   PVHUJELLJLJGLN-INIZCTEOSA-N   6         (S)-nitrendipine   80873-62-7
# 3   JRWZLRBJNMZMFE-ZDUSSCGKSA-N  13            levdobutamine   61661-06-1
# 4   TVZGACDUOSZQKY-LBPRGKRZSA-N  21              aminopterin      54-62-6
# 5   QCTBMLYLENLHLA-UHFFFAOYSA-N  22  aminomethylbenzoic acid      56-91-7
# 6   OBKXEAXTFZPCHS-UHFFFAOYSA-N  24      phenylbutanoic acid    1821-12-1
# 7   NMUSYJAQQFHJEW-KVTDHHQDSA-N  25              azacitidine     320-67-2
# 8   GHASVSINZRGABV-UHFFFAOYSA-N  26             fluorouracil      51-21-8
# 9   QQOBRRFOVWGIMD-OJAKKHQRSA-N  27                azaribine    2169-64-4
# 10  QXKHYNVANLEOEG-UHFFFAOYSA-N  30              methoxsalen     298-81-7
# 11  MDJRZSNPHZEMJH-MTMZYOSNSA-N  33         artisone acetate     566-78-9
# 12  MCGSCOLBFJQGHM-SCZZXKLOSA-N  34                 abacavir  136470-78-5
# 13  AIWRTTMUVOZGPW-HSPKUQOVSA-N  35                 abarelix  183552-38-7
# 14  RTRQQBHATOEIAF-UUOKFMHZSA-N  37                acadesine    2627-69-2

# %%
drug_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4052 entries, 0 to 4051
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4052 non-null   int64
#  1   SMILES      4052 non-null   object
#  2   InChI       4052 non-null   object
#  3   InChIKey    4052 non-null   object
#  4   ID          4052 non-null   int64
#  5   INN         4052 non-null   object
#  6   CAS_RN      4050 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 221.7+ KB

# %%
endogenous.head()
# Out:
#             zinc_id                                          smiles
# 0  ZINC000000119675                                COc1cc(CCN)ccc1O
# 1  ZINC000000120430                              COc1cccc(C(=O)O)c1
# 2  ZINC000003171672  CC1(C)C[C@H]2C(=O)CC[C@@H]3O[C@]3(C)CC[C@@H]21
# 3  ZINC000001572037          CC(C)[C@@H](NC(=O)[C@H](N)CCCCN)C(=O)O
# 4  ZINC000000895535                   O=C(O)[C@H](O)Cc1ccc(O)c(O)c1

# %%
endogenous.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81519 entries, 0 to 81518
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   zinc_id  81519 non-null  object
#  1   smiles   81519 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
in_trails.head(15)
# Out:
#              zinc_id                                             smiles
# 0   ZINC000245189325                                           O=P(=O)O
# 1   ZINC000029747110  COc1cccc2c1[C@@H]1CN(CCCCn3c(O)nc4c(sc5ncc(-c6...
# 2   ZINC000137550338  CN(C)c1cc(CNCC(C)(C)C)c(O)c2c1C[C@H]1C[C@H]3[C...
# 3   ZINC000137550409  CN(C)c1cc(CNCC(C)(C)C)c(O)c2c1C[C@H]1C[C@H]3[C...
# 4   ZINC000137550489  CN(C)c1cc(CNCC(C)(C)C)c(O)c2c1C[C@H]1C[C@H]3[C...
# 5   ZINC000005161047  Cc1ccc2c(n1)Oc1ccc([C@@H](C)C(=O)OCC(=O)N(C)C)...
# 6   ZINC000137550260  CN(C)c1cc(CNCC(C)(C)C)c(O)c2c1C[C@H]1C[C@H]3[C...
# 7   ZINC000020621755  CCOc1cc(N)c(Cl)cc1C(=O)NC[C@@H]1CN(Cc2ccc(F)cc...
# 8   ZINC000020621758  CCOc1cc(N)c(Cl)cc1C(=O)NC[C@H]1CN(Cc2ccc(F)cc2...
# 9   ZINC000035645588      CC(=O)C(=Cc1cc(O)c(O)c([N+](=O)[O-])c1)C(C)=O
# 10  ZINC000085994848  CCCCC[C@H](O)/C=C/[C@H]1C(=O)C[C@H](O)[C@@H]1C...
# 11  ZINC000004217444                O=C(O)[C@@H]1C[C@H](CP(=O)(O)O)CCN1
# 12  ZINC000000003189                    Clc1ccc([C@]23CNC[C@H]2C3)cc1Cl
# 13  ZINC000004216433  CC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(=O)O)C(=O)NCC...
# 14  ZINC000003830976  CC[C@H](C)n1ncn(-c2ccc(N3CCN(c4ccc(OC[C@H]5CO[...

# %%
in_trails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   zinc_id  9800 non-null   object
#  1   smiles   9800 non-null   object
# dtypes: object(2)
# memory usage: 153.2+ KB

# %%
world.head()
# Out:
#             zinc_id                                             smiles
# 0  ZINC000001532673                  N[C@@H](CSSC[C@H](N)C(=O)O)C(=O)O
# 1  ZINC000001408068                               O=C(O)c1cc(O)nc(O)n1
# 2  ZINC000001532582                              NC(=O)CCCC[C@H]1CCSS1
# 3  ZINC000003830381  CCCCC[C@](C)(O)/C=C/[C@H]1[C@H](O)C[C@H](O)[C@...
# 4  ZINC000003830394  Cn1nnnc1SCC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H...

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5903 entries, 0 to 5902
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   zinc_id  5903 non-null   object
#  1   smiles   5903 non-null   object
# dtypes: object(2)
# memory usage: 92.4+ KB
