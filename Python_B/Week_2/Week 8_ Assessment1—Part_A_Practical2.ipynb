# %% [markdown]
# # Q1 Inheritance and Polymorphism Relationships

# %%
# creating superclass

class PC:
    def __init__(self, Id, perfomance_cpu):
        self.Id = Id
        self.perfomance_cpu = perfomance_cpu
        
    def __repr__(self):
        return ("PC ID of "+str(self.Id)+" scored " +str(self.perfomance_cpu)+" in the cpu stress test"+"\n")
    def TurnOn(self):
        print("The PC is turned on")
    
    def TurnOff(self):
        print("The PC is Turned Off")
        
    # to facilitate sorting fucntionality
    # according to cpu performace
    ##################################################################
    
    def __lt__(self,other):
        return self.perfomance_cpu<other.perfomance_cpu
    
    def __eq__(self,other):
        self.perfomance_cpu==other.perfomance_cpu
    ##################################################################    
        

# creating subclass       
class HPC(PC):
    # Inheritance
    def __init__(self, Id, perfomance_cpu, perfomance_gpu):
        
        PC.__init__(self, Id, perfomance_cpu)
        
        self.perfomance_gpu = perfomance_gpu
    # for printing
    def __repr__(self):
        return ("HPC ID of "+str(self.Id)+" scored " +str(self.perfomance_cpu)
                +" in the cpu stress test and scored "
                +str(self.perfomance_gpu)+" in the GPU stress test"+"\n")
    # to facilitate sorting fucntionality
    # according to cpu performace
    ##################################################################
    def __lt__(self,other):
        return self.perfomance_cpu<other.perfomance_cpu
    
    def __eq__(self,other):
        self.perfomance_cpu==other.perfomance_cpu
    ##################################################################
    
    def TurnOn(self):
        print("The HPC is turned on")
    
    def TurnOff(self):
        print("The HPC is Turned Off")
        
    def Simulation_On(self):
        print("The Simualtion has started")
    
    def Simulation_Off(self):
        print("The Simulation has ended")
    
    
# creating subclass   
class Laptop(PC):
    # Inheritance
    def __init__(self, Id, perfomance_cpu, Battery):
        PC.__init__(self, Id, perfomance_cpu)
            
        self.Battery = Battery
        
        
    # for printing        
    def __repr__(self):
        
        return ("Laptop ID of "+str(self.Id)+" scored " +str(self.perfomance_cpu)
                +" in the cpu stress test and lasted for "
                +str(self.Battery)+" hours "+"\n")
    # to facilitate sorting fucntionality
    # according to cpu performace
    ##################################################################
    def __lt__(self,other):
        return self.perfomance_cpu<other.perfomance_cpu
    
    def __eq__(self,other):
        self.perfomance_cpu==other.perfomance_cpu
    ##################################################################
    
    def TurnOn(self):
        print("The Laptop is turned on")
    
    def TurnOff(self):
        print("The Laptop is Turned Off")
        
    def Battery_Low(Self):
        print("Battery life is low please connect the charger")
    
    def Warning (self):
        print("Battrey is low. system will shutoff")

# %%
pc_list = []
# create objects from three classes and add them all into a list. 
# as each list entry represent an object. 
for i in range(2,14,3):
    p=PC(i, (i*20))
    h=HPC(i,(i*30),(i*50))
    l=Laptop(i, (i*10), (i-1))
    pc_list.append(p)
    pc_list.append(h)
    pc_list.append(l)
# loop over each object and activating a fucntion according to the object. 
# here Inheritance and Polymorphism should be evident. 
for pc in pc_list:
    pc.TurnOn()
    pc.TurnOff()
    if isinstance(pc,HPC):
        pc.Simulation_On()
        pc.Simulation_Off()
    if isinstance(pc,Laptop):
        pc.Battery_Low()
        pc.Warning()
# Out:
# The PC is turned on
# The PC is Turned Off
# The HPC is turned on
# The HPC is Turned Off
# The Simualtion has started
# The Simulation has ended
# The Laptop is turned on
# The Laptop is Turned Off
# Battery life is low please connect the charger
# Battrey is low. system will shutoff
# The PC is turned on
# The PC is Turned Off
# The HPC is turned on
# The HPC is Turned Off
# The Simualtion has started
# The Simulation has ended
# The Laptop is turned on
# The Laptop is Turned Off
# Battery life is low please connect the charger
# Battrey is low. system will shutoff
# The PC is turned on
# The PC is Turned Off
# The HPC is turned on
# The HPC is Turned Off
# The Simualtion has started
# The Simulation has ended
# The Laptop is turned on
# The Laptop is Turned Off
# Battery life is low please connect the charger
# Battrey is low. system will shutoff
# The PC is turned on
# The PC is Turned Off
# The HPC is turned on
# The HPC is Turned Off
# The Simualtion has started
# ...

# %%
# calling the objects should initialize the __repr__ fucntion.
print(pc_list)
# Out:
# [PC ID of 2 scored 40 in the cpu stress test
# , HPC ID of 2 scored 60 in the cpu stress test and scored 100 in the GPU stress test
# , Laptop ID of 2 scored 20 in the cpu stress test and lasted for 1 hours
# , PC ID of 5 scored 100 in the cpu stress test
# , HPC ID of 5 scored 150 in the cpu stress test and scored 250 in the GPU stress test
# , Laptop ID of 5 scored 50 in the cpu stress test and lasted for 4 hours
# , PC ID of 8 scored 160 in the cpu stress test
# , HPC ID of 8 scored 240 in the cpu stress test and scored 400 in the GPU stress test
# , Laptop ID of 8 scored 80 in the cpu stress test and lasted for 7 hours
# , PC ID of 11 scored 220 in the cpu stress test
# , HPC ID of 11 scored 330 in the cpu stress test and scored 550 in the GPU stress test
# , Laptop ID of 11 scored 110 in the cpu stress test and lasted for 10 hours
# ]

# %% [markdown]
# # Q1 Sort ascending and descending.

# %%
# sorting according to pc performance. 
pc_ascending = sorted(pc_list)
pc_descending = sorted(pc_list,reverse=True)

print(pc_ascending)

print("\n")

print(pc_descending)
# Out:
# [Laptop ID of 2 scored 20 in the cpu stress test and lasted for 1 hours
# , PC ID of 2 scored 40 in the cpu stress test
# , Laptop ID of 5 scored 50 in the cpu stress test and lasted for 4 hours
# , HPC ID of 2 scored 60 in the cpu stress test and scored 100 in the GPU stress test
# , Laptop ID of 8 scored 80 in the cpu stress test and lasted for 7 hours
# , PC ID of 5 scored 100 in the cpu stress test
# , Laptop ID of 11 scored 110 in the cpu stress test and lasted for 10 hours
# , HPC ID of 5 scored 150 in the cpu stress test and scored 250 in the GPU stress test
# , PC ID of 8 scored 160 in the cpu stress test
# , PC ID of 11 scored 220 in the cpu stress test
# , HPC ID of 8 scored 240 in the cpu stress test and scored 400 in the GPU stress test
# , HPC ID of 11 scored 330 in the cpu stress test and scored 550 in the GPU stress test
# ]
#
#
# [HPC ID of 11 scored 330 in the cpu stress test and scored 550 in the GPU stress test
# ...

# %% [markdown]
# # Q2

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Testing

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']})

# %%
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'], 'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left.head()
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right.head()
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
union = pd.concat([left, right], sort=False)

# %%
union
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0  NaN  NaN
# 1  K1   A1   B1  NaN  NaN
# 2  K2   A2   B2  NaN  NaN
# 3  K3   A3   B3  NaN  NaN
# 0  K0  NaN  NaN   C0   D0
# 1  K1  NaN  NaN   C1   D1
# 2  K2  NaN  NaN   C2   D2
# 3  K3  NaN  NaN   C3   D3

# %% [markdown]
# # Q2 Union of two DataFrames
# ### Data source:  https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset

# %%
df_data_fake = pd.DataFrame(pd.read_csv("Fake.csv"))
df_data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# #### Add a label so we can seprate between the two dataset once they are combined.

# %%
#creating a label for the fake dataset.
df_data_fake["label"] = "Fake"

# %%
df_data_fake.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date  label
# count          23481  23481
# unique          1681      1
# top     May 10, 2017   Fake
# freq              46  23481

# %%
df_data_true = pd.DataFrame(pd.read_csv("True.csv"))
df_data_true.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
#creating a label for the true dataset.
df_data_true["label"] = "True"

# %%
# %timeit df_data_union = pd.concat([df_data_true, df_data_fake], sort=False)
# Out:
# 2.45 ms ± 85.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df_data_union = pd.concat([df_data_true, df_data_fake], sort=False)

# %% [markdown]
# #### The two datasets combined

# %%
df_data_union.head(-1)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
df_data_union.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  object
# dtypes: object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# # Q3 Merge of two DataFrames

# %% [markdown]
# ### Shape file : https://beta.abs.gov.au/statistics/people/population/regional-population/2018-19
#
# ### Data : https://www.abs.gov.au/AUSSTATS/abs@.nsf/DetailsPage/1270.0.55.001July%202016?OpenDocument#Data

# %%
# read the population density dataset 
excel_data = pd.DataFrame(pd.read_excel("32180ds0001_2018-19.xls", sheet_name=4, header=7))

# %%
excel_data.head(-5)
# Out:
#     S/T code         S/T name GCCSA code        GCCSA name  SA4 code  \
# 0        NaN              NaN        NaN               NaN       NaN
# 1          4  South Australia      4GADE  Greater Adelaide     401.0
# 2          4  South Australia      4GADE  Greater Adelaide     401.0
# 3          4  South Australia      4GADE  Greater Adelaide     401.0
# 4          4  South Australia      4GADE  Greater Adelaide     401.0
# ..       ...              ...        ...               ...       ...
# 170        4  South Australia      4RSAU        Rest of SA     407.0
# 171        4  South Australia      4RSAU        Rest of SA     407.0
# 172        4  South Australia      4RSAU        Rest of SA     407.0
# 173      NaN              NaN        NaN               NaN       NaN
# 174      NaN              NaN        NaN               NaN       NaN
#
#                          SA4 name  SA3 code           SA3 name     SA2 code  \
# ...

# %%
# Extract only the needed information for the density plot
excel_data = excel_data[["S/T name","SA2 code","persons/km2"]]

# %% [markdown]
# ### Clean the excel dataset

# %%
excel_data.head(-1)
# Out:
#             S/T name     SA2 code  persons/km2
# 0                NaN          NaN          NaN
# 1    South Australia  401011001.0       1726.9
# 2    South Australia  401011002.0       1444.5
# 3    South Australia  401021003.0         19.2
# 4    South Australia  401021004.0        153.7
# ..               ...          ...          ...
# 174              NaN          NaN          1.8
# 175              NaN          NaN          NaN
# 176              NaN          NaN          NaN
# 177              NaN          NaN          NaN
# 178              NaN          NaN          NaN
#
# [179 rows x 3 columns]

# %%
excel_data.dropna()
# Out:
#             S/T name     SA2 code  persons/km2
# 1    South Australia  401011001.0       1726.9
# 2    South Australia  401011002.0       1444.5
# 3    South Australia  401021003.0         19.2
# 4    South Australia  401021004.0        153.7
# 5    South Australia  401021005.0         41.7
# ..               ...          ...          ...
# 168  South Australia  407031166.0          2.0
# 169  South Australia  407031167.0        329.8
# 170  South Australia  407031168.0          5.6
# 171  South Australia  407031169.0          0.6
# 172  South Australia  407031170.0          1.2
#
# [172 rows x 3 columns]

# %%
excel_data = excel_data[excel_data["S/T name"]=="South Australia"]

# %%
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 1 to 172
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   S/T name     172 non-null    object
#  1   SA2 code     172 non-null    float64
#  2   persons/km2  172 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.4+ KB

# %%
# rename the column so it can be merged be column name. 
excel_data.rename(columns={'SA2 code':'SA2_MAIN16'},inplace= True)

# %%
import geopandas as gpd

# %%
map_SA = gpd.read_file('SA2_2016_AUST.shp',)

# %%
map_SA = map_SA[map_SA["STE_NAME16"]=="South Australia"]

# %%
map_SA.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 174 entries, 1572 to 1745
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SA2_MAIN16  174 non-null    object
#  1   SA2_5DIG16  174 non-null    object
#  2   SA2_NAME16  174 non-null    object
#  3   SA3_CODE16  174 non-null    object
#  4   SA3_NAME16  174 non-null    object
#  5   SA4_CODE16  174 non-null    object
#  6   SA4_NAME16  174 non-null    object
#  7   GCC_CODE16  174 non-null    object
#  8   GCC_NAME16  174 non-null    object
#  9   STE_CODE16  174 non-null    object
#  10  STE_NAME16  174 non-null    object
#  11  AREASQKM16  174 non-null    float64
#  12  geometry    172 non-null    geometry
# dtypes: float64(1), geometry(1), object(11)
# memory usage: 19.0+ KB

# %%
map_SA.head(-1)
# Out:
#      SA2_MAIN16 SA2_5DIG16                            SA2_NAME16 SA3_CODE16  \
# 1572  401011001      41001                              Adelaide      40101
# 1573  401011002      41002                        North Adelaide      40101
# 1574  401021003      41003                        Adelaide Hills      40102
# 1575  401021004      41004                    Aldgate - Stirling      40102
# 1576  401021005      41005                    Hahndorf - Echunga      40102
# ...         ...        ...                                   ...        ...
# 1740  407031167      41167                               Renmark      40703
# 1741  407031168      41168                        Renmark Region      40703
# 1742  407031169      41169                           The Coorong      40703
# 1743  407031170      41170                              Waikerie      40703
# 1744  497979799      49799  Migratory - Offshore - Shipping (SA)      49797
#
#                                 SA3_NAME16 SA4_CODE16  \
# ...

# %% [markdown]
# ### Clean the shapefile

# %%
# Extract only the needed information for the density plot
map_SA = map_SA[["STE_NAME16","SA2_MAIN16","geometry"]]

# %%
map_SA.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 174 entries, 1572 to 1745
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STE_NAME16  174 non-null    object
#  1   SA2_MAIN16  174 non-null    object
#  2   geometry    172 non-null    geometry
# dtypes: geometry(1), object(2)
# memory usage: 5.4+ KB

# %%
map_SA['SA2_MAIN16']=map_SA['SA2_MAIN16'].astype(float)

# %% [markdown]
# ### Merge the two datasets

# %%
# Merge by SA2_MAIN16 column
# %timeit  map_SA_den = map_SA.merge(excel_data, on= 'SA2_MAIN16', how='outer')
# Out:
# 2.15 ms ± 76.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
map_SA_den = map_SA.merge(excel_data, on= 'SA2_MAIN16', how='outer')

# %%
map_SA_den.head()
# Out:
#         STE_NAME16   SA2_MAIN16  \
# 0  South Australia  401011001.0
# 1  South Australia  401011002.0
# 2  South Australia  401021003.0
# 3  South Australia  401021004.0
# 4  South Australia  401021005.0
#
#                                             geometry         S/T name  \
# 0  POLYGON ((138.58096 -34.93024, 138.58094 -34.9...  South Australia
# 1  POLYGON ((138.58214 -34.90424, 138.58287 -34.9...  South Australia
# 2  POLYGON ((138.75610 -34.82107, 138.75567 -34.8...  South Australia
# 3  POLYGON ((138.69440 -34.98807, 138.69514 -34.9...  South Australia
# 4  POLYGON ((138.78877 -35.02474, 138.78889 -35.0...  South Australia
#
#    persons/km2
# 0       1726.9
# 1       1444.5
# 2         19.2
# 3        153.7
# 4         41.7

# %% [markdown]
# # SA Population Density Map.

# %%
import matplotlib.pyplot as plt
# plot the results
f, ax = plt.subplots(1,figsize=(20,15))
ax = map_SA_den.plot(ax=ax,column='persons/km2',cmap = 'tab20c',legend= True)
ax.set_axis_off()
plt.show()
