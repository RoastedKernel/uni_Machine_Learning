# %%
# Common imports
import numpy as np
import os
import os
import tarfile
import urllib
import pandas as pd
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
col_names = ["fixed acidity", "volatile acidity", "citric acid",
             "residual sugar", "chlorides", "free sulfur dioxide", 
             "total sulfur dioxide", "density", "pH", "sulphates", "alcohol", "quality", "extra"]
wine = pd.read_csv("winedata.csv", delimiter=";", error_bad_lines=False)
# Out:
# b'Skipping line 3149: expected 12 fields, saw 13\nSkipping line 4821: expected 12 fields, saw 13\n'

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4896 entries, 0 to 4895
# Data columns (total 12 columns):
# fixed acidity           4891 non-null float64
# volatile acidity        4891 non-null object
# citric acid             4843 non-null object
# residual sugar          4886 non-null object
# chlorides               4890 non-null object
# free sulfur dioxide     4888 non-null object
# total sulfur dioxide    4889 non-null object
# density                 4890 non-null object
# pH                      4890 non-null object
# sulphates               4892 non-null object
# alcohol                 4890 non-null object
# quality                 4892 non-null object
# dtypes: float64(1), object(11)
# memory usage: 459.1+ KB

# %%
wine.describe()
# Out:
#        fixed acidity
# count    4891.000000
# mean        6.855030
# std         0.844023
# min         3.800000
# 25%         6.300000
# 50%         6.800000
# 75%         7.300000
# max        14.200000

# %%
wine.head()
# Out:
#    fixed acidity volatile acidity citric acid residual sugar  \
# 0            7.0             0.27        0.36           20.7
# 1            6.3              0.3        0.34            1.6
# 2            8.1             0.28         0.4            6.9
# 3            7.2             0.23        0.32            8.5
# 4            7.2             0.23        0.32            8.5
#
#               chlorides free sulfur dioxide total sulfur dioxide  \
# 0                 0.045                45.0                170.0
# 1                 0.049                14.0                132.0
# 2                  0.05                30.0                 97.0
# 3  0.057999999999999996                47.0                186.0
# 4  0.057999999999999996                47.0                186.0
#
#               density    pH sulphates alcohol quality
# 0               1.001   3.0      0.45     8.8       6
# 1  0.9940000000000001   3.3      0.49     9.5       6
# 2              0.9951  3.26      0.44    10.1       6
# 3              0.9956  3.19       0.4     9.9       6
# 4              0.9956  3.19       0.4     9.9       6

# %%
drop_high = wine[(wine['quality'] == 'high') | (wine['quality']== 'low') | (wine['quality']== ' ') ].index
#drop_low = wine[wine['quality']== 'low'].index
wine_no_high = wine.drop(drop_high)
wine_clean = wine_no_high.dropna()
#wine_nostr = wine_no_high.drop(drop_low)
wine_float = wine_clean.astype(float)
#wine___nostr = wine.dropna()

# %%
wine_float.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4736.000000       4736.000000  4736.000000     4736.000000
# mean        6.856197          0.277719     0.334388        6.401024
# std         0.844487          0.100313     0.121084        5.091559
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4736.000000          4736.000000           4736.000000  4736.000000
# mean      0.045863            35.350084            138.473395     0.994037
# std       0.021971            17.036944             42.543137     0.002998
# min       0.009000             2.000000             10.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991720
# 50%       0.043000            34.000000            134.000000     0.993780
# 75%       0.050000            46.000000            167.000000     0.996120
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4736.000000  4736.000000  4736.000000  4736.000000
# mean      3.188547     0.489962    10.511218     5.877111
# std       0.151226     0.114152     1.226792     0.885705
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
wine_float.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8      6.0
# 1      9.5      6.0
# 2     10.1      6.0
# 3      9.9      6.0
# 4      9.9      6.0
